# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Limit calculations using deterministic ODEs

# %%
# steady state for mRNA level
def m(omega, k0, k1):
    return omega * (k0 / k1)

# %%
k0 = 0.2
k1 = 0.01
omega = 1

print(m(omega, k0, k1))
# Out:
# 20.0

# %% [markdown]
# ## Mean Expression Level from stochastic simulation

# %%
from ssa import SSA

# %%
dt = 0.5  # time-step
x = 0  # initial state
t = 0.0

ssa = SSA(k0_production_rate_const=k0, k1_degradation_rate_const=k1)

mrna = [x]
time = [t]
for i in range(10000):
    x = ssa.compute_step(x, t, t + dt)
    t += dt
    mrna.append(x)
    time.append(t)

# %%
import matplotlib.pyplot as plt

plt.plot(time[100:], mrna[100:])

# %%
import numpy as np

timestep = 0.5
np.sum([timestep * curr_level for curr_level in mrna]) / time[-1]
# Out:
# 20.6641
